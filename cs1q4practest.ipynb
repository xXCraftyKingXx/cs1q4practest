# %% [markdown]
# <a href="https://colab.research.google.com/github/xXCraftyKingXx/cs1q4practest/blob/main/cs1q4practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q4 Cop Sci Prac Test
num_ = int(input("Enter a number: "))
if num_ % 2:
         print("The number is odd")
else:
         print("The number is even")
# Out:
# Enter a number: 8
# The number is even
# Enter first number: 3
# Enter second number: 4
